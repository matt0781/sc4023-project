# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data/ResalePricesSingapore.csv")
df
# Out:
#           month        town  flat_type block        street_name storey_range  \
# 0       2014-01  ANG MO KIO     2 ROOM   510   ANG MO KIO AVE 8     07 TO 09
# 1       2014-01  ANG MO KIO     3 ROOM   603   ANG MO KIO AVE 5     07 TO 09
# 2       2014-01  ANG MO KIO     3 ROOM   476  ANG MO KIO AVE 10     04 TO 06
# 3       2014-01  ANG MO KIO     3 ROOM   558  ANG MO KIO AVE 10     01 TO 03
# 4       2014-01  ANG MO KIO     3 ROOM   605   ANG MO KIO AVE 5     01 TO 03
# ...         ...         ...        ...   ...                ...          ...
# 222828  2024-01      YISHUN     5 ROOM   213       YISHUN ST 21     04 TO 06
# 222829  2024-01      YISHUN     5 ROOM  505C       YISHUN ST 51     04 TO 06
# 222830  2024-01      YISHUN     5 ROOM  513C       YISHUN ST 51     07 TO 09
# 222831  2024-01      YISHUN     5 ROOM   602       YISHUN ST 61     07 TO 09
# 222832  2024-01      YISHUN  EXECUTIVE   356     YISHUN RING RD     04 TO 06
#
# ...

# %%
df['group'] = np.arange(len(df)) // 1000

# %%
df.groupby(['group'])['resale_price'].max()[:20]
# Out:
# group
# 0      980000.0
# 1      888000.0
# 2      876000.0
# 3      980000.0
# 4      898000.0
# 5      980000.0
# 6      920000.0
# 7      950000.0
# 8      925000.0
# 9      960000.0
# 10     900000.0
# 11     900000.0
# 12    1088888.0
# 13     980000.0
# 14    1000000.0
# 15     910000.0
# 16     980000.0
# 17    1040000.0
# 18    1018000.0
# 19    1060000.0
# Name: resale_price, dtype: float64

# %%
df.groupby(['group'])['resale_price'].min()[:20]
# Out:
# group
# 0     235000.0
# 1     233000.0
# 2     240000.0
# 3     242000.0
# 4     244000.0
# 5     235000.0
# 6     234000.0
# 7     210000.0
# 8     230000.0
# 9     247000.0
# 10    210000.0
# 11    240000.0
# 12    195000.0
# 13    210000.0
# 14    228000.0
# 15    200000.0
# 16    210000.0
# 17    220000.0
# 18    210000.0
# 19    220000.0
# Name: resale_price, dtype: float64
